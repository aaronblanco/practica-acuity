# %% [markdown]
# <a href="https://colab.research.google.com/github/Teodosiodg2002/practica-acuity/blob/main/HousePricesKaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalación (Colab) y imports

# %%
# !pip install -q tensorflow_decision_forests
from pathlib import Path
from google.colab import drive

drive.mount('/content/drive')
# ------------- CONFIG -------------
RANDOM_STATE = 42
DATA_DIR = Path('/content/drive/MyDrive/casas')
LABEL = "PrecioVenta"
# ----------------------------------

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Train: (1460, 81) Test: (1459, 80)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# ============================================================
# 1. IMPORTS
# ============================================================
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_decision_forests as tfdf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from pathlib import Path

# ============================================================
# 2. CONFIGURACIÓN
# ============================================================
DATA_DIR = Path("/content/drive/MyDrive/casas")
TRAIN_CSV = DATA_DIR / "train.csv"
TEST_CSV  = DATA_DIR / "test.csv"
SUBMISSION_CSV = Path("submission.csv")

LABEL = "SalePrice"
TARGET = "log_SalePrice"          # usamos log1p(SalePrice) para entrenar
RANDOM_STATE = 42

# Elige el modelo aquí: "gbt" (GradientBoostedTrees) o "rf" (RandomForest)
MODEL_CHOICE = "gbt"

# Hiperparámetros
HYPERPARAMS = {
    "gbt": {
        "num_trees": 300,
        "max_depth": 6,
    },
    "rf": {
        "num_trees": 500,
        "max_depth": 16,
    }
}

# ============================================================
# 3. FUNCIÓN DE PREPROCESADO (MISMA PARA TRAIN Y TEST)
# ============================================================
def preprocess(df: pd.DataFrame) -> pd.DataFrame:
    """
    Preprocesado simple y reproducible:
      - Rellena nulos (median para numéricos, 'MISSING' para categóricos)
      - Convierte object -> str (TF-DF acepta strings como categorías)
      - NO hacemos one-hot ni escalado (TF-DF no lo necesita)
    """
    df = df.copy()
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    cat_cols = df.select_dtypes(include=["object"]).columns.tolist()

    # Rellenar numéricos con mediana
    if len(num_cols) > 0:
        medians = df[num_cols].median()
        df[num_cols] = df[num_cols].fillna(medians)

    # Rellenar categóricos con 'MISSING' y forzar str
    for c in cat_cols:
        df[c] = df[c].fillna("MISSING").astype(str)

    return df

# ============================================================
# 4. CARGAR DATOS
# ============================================================
print("Cargando datos...")
df = pd.read_csv(TRAIN_CSV)
test_df = pd.read_csv(TEST_CSV)

# Guardar Id del test para submission
if "Id" in test_df.columns:
    test_ids = test_df["Id"].copy()
    test_df = test_df.drop(columns=["Id"])
else:
    raise ValueError("No se encontró columna 'Id' en test.csv")

# Eliminar Id del train si existe
if "Id" in df.columns:
    df = df.drop(columns=["Id"])

print("Train shape:", df.shape, "Test shape:", test_df.shape)

# ============================================================
# 5. PREPROCESADO
# ============================================================
df = preprocess(df)
test_pp = preprocess(test_df)

# ============================================================
# 6. TRANSFORMAR TARGET (log1p)
# ============================================================
df[TARGET] = np.log1p(df[LABEL])

# ============================================================
# 7. SPLIT TRAIN / VALID (para controlar overfitting)
# ============================================================
train_df, valid_df = train_test_split(df, test_size=0.20, random_state=RANDOM_STATE)

print("Train/Valid sizes:", len(train_df), len(valid_df))

# ============================================================
# 8. CONVERTIR A TF DATASET (TF-DF)
# ============================================================
label_col = TARGET

train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_df.drop(columns=[LABEL]), label=label_col, task=tfdf.keras.Task.REGRESSION)
valid_ds = tfdf.keras.pd_dataframe_to_tf_dataset(valid_df.drop(columns=[LABEL]), label=label_col, task=tfdf.keras.Task.REGRESSION)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_pp, task=tfdf.keras.Task.REGRESSION)

# ============================================================
# 9. CREAR MODELO SEGÚN ELECCIÓN
# ============================================================
print(f"Creando modelo: {MODEL_CHOICE}")

if MODEL_CHOICE == "gbt":
    p = HYPERPARAMS["gbt"]
    model = tfdf.keras.GradientBoostedTreesModel(
        task=tfdf.keras.Task.REGRESSION,
        num_trees=p["num_trees"],
        max_depth=p["max_depth"],
        random_seed=RANDOM_STATE
    )
elif MODEL_CHOICE == "rf":
    p = HYPERPARAMS["rf"]
    model = tfdf.keras.RandomForestModel(
        task=tfdf.keras.Task.REGRESSION,
        num_trees=p["num_trees"],
        max_depth=p["max_depth"],
        random_seed=RANDOM_STATE
    )
else:
    raise ValueError("MODEL_CHOICE debe ser 'gbt' o 'rf'")

# ============================================================
# 10. ENTRENAMIENTO (sobre train_ds)
# ============================================================
print("Entrenando...")
model.fit(train_ds)
print("Entrenamiento finalizado.")
print(model.summary())

# ============================================================
# 11. EVALUACIÓN EN VALID
# ============================================================
preds_log_valid = model.predict(valid_ds)[:, 0]
y_true_log = valid_df[TARGET].values

rmse_log = np.sqrt(mean_squared_error(y_true_log, preds_log_valid))
print(f"RMSE en valid (log1p scale): {rmse_log:.6f}")

preds_price_valid = np.expm1(preds_log_valid)
y_true_price = np.expm1(y_true_log)
rmse_price = np.sqrt(mean_squared_error(y_true_price, preds_price_valid))
print(f"RMSE en precio (valid): {rmse_price:.2f} USD aprox.")

# ============================================================
# 12. IMPORTANCIAS (NUM_AS_ROOT)
# ============================================================
inspector = model.make_inspector()
if "NUM_AS_ROOT" in inspector.variable_importances().keys():
    vi = inspector.variable_importances()["NUM_AS_ROOT"]
    print("\nTop features (NUM_AS_ROOT):")
    for feat, score in vi[:15]:
        print(f"  - {feat.name}: {score}")
else:
    print("No hay variable importance 'NUM_AS_ROOT' disponible.")

# ============================================================
# 13. REENTRENAR EN TODO EL TRAIN
# ============================================================
RETRAIN_ON_ALL = True
if RETRAIN_ON_ALL:
    print("\nReentrenando modelo final con todo el train (train+valid)...")

    full_train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(df.drop(columns=[LABEL]), label=TARGET, task=tfdf.keras.Task.REGRESSION)

    if MODEL_CHOICE == "gbt":
        p = HYPERPARAMS["gbt"]
        final_model = tfdf.keras.GradientBoostedTreesModel(
            task=tfdf.keras.Task.REGRESSION,
            num_trees=p["num_trees"],
            max_depth=p["max_depth"],
            random_seed=RANDOM_STATE
        )
    else:
        p = HYPERPARAMS["rf"]
        final_model = tfdf.keras.RandomForestModel(
            task=tfdf.keras.Task.REGRESSION,
            num_trees=p["num_trees"],
            max_depth=p["max_depth"],
            random_seed=RANDOM_STATE
        )

    final_model.fit(full_train_ds)
    model_for_submission = final_model
else:
    model_for_submission = model

# ============================================================
# 14. PREDICCIÓN SOBRE TEST Y CREAR SUBMISSION
# ============================================================
preds_log_test = model_for_submission.predict(test_ds)[:, 0]
preds_test_price = np.expm1(preds_log_test)

submission = pd.DataFrame({
    "Id": test_ids,
    "SalePrice": preds_test_price
})
submission.to_csv(SUBMISSION_CSV, index=False)
print(submission.head())
# Out:
# Cargando datos...
# Train shape: (1460, 80) Test shape: (1459, 79)
# Train/Valid sizes: 1168 292
# Creando modelo: gbt
# Use /tmp/tmpo0kabp6n as temporary training directory
# Entrenando...
# Reading training dataset...
# Training dataset read in 0:00:00.845611. Found 1168 examples.
# Training model...
# Model trained in 0:00:02.202002
# Compiling model...
# Model compiled.
# Entrenamiento finalizado.
# Model: "gradient_boosted_trees_model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: REGRESSION
# Label: "__LABEL"
#
# Input Features (79):
# 	1stFlrSF
# 	2ndFlrSF
# 	3SsnPorch
# 	Alley
# 	BedroomAbvGr
# 	BldgType
# 	BsmtCond
# 	BsmtExposure
# 	BsmtFinSF1
# 	BsmtFinSF2
# 	BsmtFinType1
# 	BsmtFinType2
# 	BsmtFullBath
# 	BsmtHalfBath
# 	BsmtQual
# 	BsmtUnfSF
# 	CentralAir
# 	Condition1
# 	Condition2
# 	Electrical
# 	EnclosedPorch
# 	ExterCond
# 	ExterQual
# 	Exterior1st
# 	Exterior2nd
# 	Fence
# 	FireplaceQu
# 	Fireplaces
# 	Foundation
# 	FullBath
# 	Functional
# 	GarageArea
# 	GarageCars
# 	GarageCond
# 	GarageFinish
# 	GarageQual
# 	GarageType
# 	GarageYrBlt
# 	GrLivArea
# 	HalfBath
# 	Heating
# 	HeatingQC
# 	HouseStyle
# 	KitchenAbvGr
# 	KitchenQual
# 	LandContour
# 	LandSlope
# 	LotArea
# 	LotConfig
# 	LotFrontage
# 	LotShape
# 	LowQualFinSF
# 	MSSubClass
# 	MSZoning
# 	MasVnrArea
# 	MasVnrType
# 	MiscFeature
# 	MiscVal
# 	MoSold
# 	Neighborhood
# 	OpenPorchSF
# 	OverallCond
# 	OverallQual
# 	PavedDrive
# 	PoolArea
# 	PoolQC
# 	RoofMatl
# 	RoofStyle
# 	SaleCondition
# 	SaleType
# 	ScreenPorch
# 	Street
# 	TotRmsAbvGrd
# 	TotalBsmtSF
# 	Utilities
# 	WoodDeckSF
# 	YearBuilt
# 	YearRemodAdd
# 	YrSold
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "GrLivArea"  0.259484 ################
#     2.  "Neighborhood"  0.232681 ###########
#     3.   "OverallQual"  0.222402 #########
#     4.  "YearRemodAdd"  0.196036 ####
#     5.    "BsmtFinSF1"  0.189645 ###
#     6.   "OpenPorchSF"  0.188884 ###
#     7.       "LotArea"  0.187778 ##
#     8.    "GarageArea"  0.185354 ##
#     9.   "OverallCond"  0.185332 ##
#    10.   "KitchenQual"  0.184857 ##
#    11.   "FireplaceQu"  0.184346 ##
#    12.  "GarageFinish"  0.184108 ##
#    13.   "TotalBsmtSF"  0.182952 #
#    14.    "GarageCars"  0.181573 #
#    15.  "BsmtExposure"  0.180591 #
#    16.    "Functional"  0.179890 #
#    17.    "Condition1"  0.179609 #
#    18.      "1stFlrSF"  0.178798 #
#    19.     "YearBuilt"  0.178323 #
#    20.    "WoodDeckSF"  0.178171 #
#    21.  "BsmtFinType1"  0.178169 #
#    22.     "LotConfig"  0.178086 #
#    23.   "GarageYrBlt"  0.177743
#    24.   "ScreenPorch"  0.177651
#    25. "SaleCondition"  0.177101
#    26.     "HeatingQC"  0.176622
#    27.   "Exterior1st"  0.176373
#    28.    "Fireplaces"  0.175567
#    29.   "Exterior2nd"  0.175541
#    30.         "Fence"  0.175122
#    31.    "GarageType"  0.175021
#    32.   "LotFrontage"  0.174853
#    33.    "CentralAir"  0.174694
#    34.      "BsmtQual"  0.174680
#    35.        "MoSold"  0.174234
#    36.        "YrSold"  0.174151
#    37.  "TotRmsAbvGrd"  0.174081
#    38.     "BsmtUnfSF"  0.173997
#    39. "EnclosedPorch"  0.173958
#    40.    "BsmtFinSF2"  0.173894
#    41.     "RoofStyle"  0.173796
#    42.      "2ndFlrSF"  0.173755
#    43.  "BsmtFullBath"  0.173599
#    44.    "GarageQual"  0.173598
#    45.    "MasVnrArea"  0.173177
#    46.      "BsmtCond"  0.173124
#    47.   "LandContour"  0.173118
#    48.    "GarageCond"  0.173109
#    49.  "KitchenAbvGr"  0.173029
#    50.     "ExterQual"  0.172778
#    51.      "MSZoning"  0.172774
#    52.    "HouseStyle"  0.172759
#    53.    "MSSubClass"  0.172731
#    54.    "PavedDrive"  0.172656
#    55.  "BedroomAbvGr"  0.172561
#    56.     "ExterCond"  0.172459
#    57.      "LotShape"  0.172408
#    58.      "SaleType"  0.172400
#    59.    "Foundation"  0.172371
#    60.    "MasVnrType"  0.172331
#    61.      "FullBath"  0.172326
#    62.      "HalfBath"  0.172326
#    63.      "BldgType"  0.172323
#
# Variable Importance: NUM_AS_ROOT:
#     1.  "OverallQual" 12.000000 ################
#     2.    "GrLivArea"  9.000000 ###########
#     3. "YearRemodAdd"  6.000000 #######
#     4.  "OpenPorchSF"  5.000000 #####
#     5. "GarageFinish"  4.000000 ####
#     6.  "KitchenQual"  3.000000 ##
#     7.      "LotArea"  3.000000 ##
#     8. "Neighborhood"  3.000000 ##
#     9.  "FireplaceQu"  1.000000
#    10.   "Functional"  1.000000
#    11.   "GarageArea"  1.000000
#    12.   "GarageCars"  1.000000
#    13.  "GarageYrBlt"  1.000000
#    14.    "HeatingQC"  1.000000
#    15.    "LotConfig"  1.000000
#    16.   "WoodDeckSF"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.  "Neighborhood" 200.000000 ################
#     2.     "GrLivArea" 131.000000 ##########
#     3.    "BsmtFinSF1" 61.000000 ####
#     4.       "LotArea" 60.000000 ####
#     5.   "TotalBsmtSF" 47.000000 ###
#     6.   "OverallCond" 45.000000 ###
#     7.   "Exterior1st" 44.000000 ###
#     8.      "1stFlrSF" 42.000000 ###
#     9.   "OverallQual" 40.000000 ###
#    10.    "GarageArea" 37.000000 ##
#    11.  "BsmtFinType1" 33.000000 ##
#    12. "SaleCondition" 33.000000 ##
#    13.  "YearRemodAdd" 33.000000 ##
#    14.     "YearBuilt" 30.000000 ##
#    15.   "OpenPorchSF" 28.000000 ##
#    16.   "Exterior2nd" 27.000000 ##
#    17.  "BsmtExposure" 25.000000 #
#    18.        "MoSold" 23.000000 #
#    19.   "FireplaceQu" 22.000000 #
#    20.     "BsmtUnfSF" 21.000000 #
#    21.   "GarageYrBlt" 20.000000 #
#    22.      "2ndFlrSF" 19.000000 #
#    23.   "KitchenQual" 19.000000 #
#    24.    "Functional" 17.000000 #
#    25.    "WoodDeckSF" 17.000000 #
#    26.   "LotFrontage" 16.000000 #
#    27.   "ScreenPorch" 16.000000 #
#    28.    "Condition1" 15.000000 #
#    29.     "LotConfig" 15.000000 #
#    30.    "GarageType" 14.000000 #
#    31.      "BsmtQual" 13.000000
#    32.    "GarageCars" 12.000000
#    33.         "Fence" 11.000000
#    34.    "MasVnrArea" 11.000000
#    35.     "HeatingQC" 10.000000
#    36.        "YrSold" 10.000000
#    37.    "CentralAir"  9.000000
#    38.  "GarageFinish"  9.000000
#    39. "EnclosedPorch"  8.000000
#    40.  "BedroomAbvGr"  7.000000
#    41.      "BsmtCond"  7.000000
#    42.    "Fireplaces"  7.000000
#    43.    "HouseStyle"  7.000000
#    44.  "TotRmsAbvGrd"  7.000000
#    45.  "BsmtFullBath"  6.000000
#    46.    "GarageQual"  6.000000
#    47.   "LandContour"  6.000000
#    48.    "MSSubClass"  6.000000
#    49.    "PavedDrive"  6.000000
#    50.     "RoofStyle"  6.000000
#    51.     "ExterCond"  4.000000
#    52.     "ExterQual"  4.000000
#    53.    "GarageCond"  4.000000
#    54.    "BsmtFinSF2"  3.000000
#    55.  "KitchenAbvGr"  3.000000
#    56.      "MSZoning"  3.000000
#    57.      "SaleType"  3.000000
#    58.    "Foundation"  2.000000
#    59.      "BldgType"  1.000000
#    60.      "FullBath"  1.000000
#    61.      "HalfBath"  1.000000
#    62.      "LotShape"  1.000000
#    63.    "MasVnrType"  1.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "OverallQual" 389.506706 ################
#     2.     "GrLivArea" 111.832774 ####
#     3.  "Neighborhood" 108.080307 ####
#     4.    "GarageCars" 24.509800 #
#     5.   "TotalBsmtSF" 20.140501
#     6.   "KitchenQual" 19.428998
#     7.    "BsmtFinSF1" 16.830719
#     8.      "1stFlrSF" 15.306344
#     9.    "CentralAir" 12.018917
#    10.    "GarageArea" 10.575560
#    11.   "OverallCond"  9.519836
#    12.       "LotArea"  8.596914
#    13.  "YearRemodAdd"  7.440041
#    14.     "YearBuilt"  7.373241
#    15.   "FireplaceQu"  5.706043
#    16.    "GarageCond"  5.539003
#    17.  "GarageFinish"  5.018014
#    18.    "GarageType"  4.266413
#    19.  "BsmtFinType1"  3.735226
#    20. "SaleCondition"  3.705165
#    21.      "BsmtCond"  2.813524
#    22.      "BsmtQual"  2.641047
#    23.   "Exterior1st"  2.626487
#    24.   "Exterior2nd"  2.536961
#    25.      "2ndFlrSF"  2.457120
#    26.   "OpenPorchSF"  2.404478
#    27.  "BsmtExposure"  2.220122
#    28.    "Fireplaces"  1.961192
#    29.     "ExterQual"  1.790567
#    30.   "GarageYrBlt"  1.633871
#    31.    "GarageQual"  1.566885
#    32.    "Functional"  1.482853
#    33.   "LotFrontage"  1.467769
#    34.  "BsmtFullBath"  1.407877
#    35.     "BsmtUnfSF"  1.407284
#    36.     "ExterCond"  1.406208
#    37.     "HeatingQC"  1.180362
#    38.    "WoodDeckSF"  1.145208
#    39.    "PavedDrive"  1.109068
#    40.  "KitchenAbvGr"  1.022769
#    41.         "Fence"  1.008756
#    42.    "MasVnrArea"  0.966353
#    43.    "Condition1"  0.951359
#    44.        "MoSold"  0.861727
#    45.   "ScreenPorch"  0.683043
#    46. "EnclosedPorch"  0.627871
#    47.        "YrSold"  0.590364
#    48.      "SaleType"  0.574684
#    49.    "HouseStyle"  0.504486
#    50.   "LandContour"  0.443330
#    51.      "BldgType"  0.441081
#    52.     "LotConfig"  0.407228
#    53.  "BedroomAbvGr"  0.400638
#    54.     "RoofStyle"  0.290349
#    55.    "MSSubClass"  0.233760
#    56.  "TotRmsAbvGrd"  0.213918
#    57.      "FullBath"  0.206046
#    58.      "MSZoning"  0.175843
#    59.    "BsmtFinSF2"  0.126037
#    60.      "HalfBath"  0.041846
#    61.    "Foundation"  0.034136
#    62.    "MasVnrType"  0.017629
#    63.      "LotShape"  0.006637
#
#
#
# Loss: SQUARED_ERROR
# Validation loss value: 0.100585
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 53
# Total number of nodes: 2743
#
# Number of nodes by tree:
# Count: 53 Average: 51.7547 StdDev: 8.1609
# Min: 29 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 29, 30) 1   1.89%   1.89% #
# [ 30, 32) 1   1.89%   3.77% #
# [ 32, 34) 1   1.89%   5.66% #
# [ 34, 36) 1   1.89%   7.55% #
# [ 36, 37) 0   0.00%   7.55%
# [ 37, 39) 1   1.89%   9.43% #
# [ 39, 41) 1   1.89%  11.32% #
# [ 41, 43) 0   0.00%  11.32%
# [ 43, 44) 2   3.77%  15.09% ###
# [ 44, 46) 2   3.77%  18.87% ###
# [ 46, 48) 2   3.77%  22.64% ###
# [ 48, 50) 8  15.09%  37.74% ##########
# [ 50, 51) 0   0.00%  37.74%
# [ 51, 53) 1   1.89%  39.62% #
# [ 53, 55) 7  13.21%  52.83% #########
# [ 55, 57) 6  11.32%  64.15% ########
# [ 57, 58) 7  13.21%  77.36% #########
# [ 58, 60) 6  11.32%  88.68% ########
# [ 60, 62) 3   5.66%  94.34% ####
# [ 62, 63] 3   5.66% 100.00% ####
#
# Depth by leafs:
# Count: 1398 Average: 4.8269 StdDev: 0.457108
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    1   0.07%   0.07%
# [ 2, 3)    5   0.36%   0.43%
# [ 3, 4)   25   1.79%   2.22%
# [ 4, 5)  173  12.37%  14.59% #
# [ 5, 5] 1194  85.41% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1398 Average: 39.2382 StdDev: 64.7332
# Min: 5 Max: 674 Ignored: 0
# ----------------------------------------------
# [   5,  38) 1009  72.17%  72.17% ##########
# [  38,  72)  161  11.52%  83.69% ##
# [  72, 105)   92   6.58%  90.27% #
# [ 105, 139)   54   3.86%  94.13% #
# [ 139, 172)   33   2.36%  96.49%
# [ 172, 206)   14   1.00%  97.50%
# [ 206, 239)    9   0.64%  98.14%
# [ 239, 273)    3   0.21%  98.35%
# [ 273, 306)    2   0.14%  98.50%
# [ 306, 340)    6   0.43%  98.93%
# [ 340, 373)    5   0.36%  99.28%
# [ 373, 407)    1   0.07%  99.36%
# [ 407, 440)    2   0.14%  99.50%
# [ 440, 474)    2   0.14%  99.64%
# [ 474, 507)    1   0.07%  99.71%
# [ 507, 541)    2   0.14%  99.86%
# [ 541, 574)    0   0.00%  99.86%
# [ 574, 608)    0   0.00%  99.86%
# [ 608, 641)    0   0.00%  99.86%
# [ 641, 674]    2   0.14% 100.00%
#
# Attribute in nodes:
# 	200 : Neighborhood [CATEGORICAL]
# 	131 : GrLivArea [NUMERICAL]
# 	61 : BsmtFinSF1 [NUMERICAL]
# 	60 : LotArea [NUMERICAL]
# 	47 : TotalBsmtSF [NUMERICAL]
# 	45 : OverallCond [NUMERICAL]
# 	44 : Exterior1st [CATEGORICAL]
# 	42 : 1stFlrSF [NUMERICAL]
# 	40 : OverallQual [NUMERICAL]
# 	37 : GarageArea [NUMERICAL]
# 	33 : YearRemodAdd [NUMERICAL]
# 	33 : SaleCondition [CATEGORICAL]
# 	33 : BsmtFinType1 [CATEGORICAL]
# 	30 : YearBuilt [NUMERICAL]
# 	28 : OpenPorchSF [NUMERICAL]
# 	27 : Exterior2nd [CATEGORICAL]
# 	25 : BsmtExposure [CATEGORICAL]
# 	23 : MoSold [NUMERICAL]
# 	22 : FireplaceQu [CATEGORICAL]
# 	21 : BsmtUnfSF [NUMERICAL]
# 	20 : GarageYrBlt [NUMERICAL]
# 	19 : KitchenQual [CATEGORICAL]
# 	19 : 2ndFlrSF [NUMERICAL]
# 	17 : WoodDeckSF [NUMERICAL]
# 	17 : Functional [CATEGORICAL]
# 	16 : ScreenPorch [NUMERICAL]
# 	16 : LotFrontage [NUMERICAL]
# 	15 : LotConfig [CATEGORICAL]
# 	15 : Condition1 [CATEGORICAL]
# 	14 : GarageType [CATEGORICAL]
# 	13 : BsmtQual [CATEGORICAL]
# 	12 : GarageCars [NUMERICAL]
# 	11 : MasVnrArea [NUMERICAL]
# 	11 : Fence [CATEGORICAL]
# 	10 : YrSold [NUMERICAL]
# 	10 : HeatingQC [CATEGORICAL]
# 	9 : GarageFinish [CATEGORICAL]
# 	9 : CentralAir [CATEGORICAL]
# 	8 : EnclosedPorch [NUMERICAL]
# 	7 : TotRmsAbvGrd [NUMERICAL]
# 	7 : HouseStyle [CATEGORICAL]
# 	7 : Fireplaces [NUMERICAL]
# 	7 : BsmtCond [CATEGORICAL]
# 	7 : BedroomAbvGr [NUMERICAL]
# 	6 : RoofStyle [CATEGORICAL]
# 	6 : PavedDrive [CATEGORICAL]
# 	6 : MSSubClass [NUMERICAL]
# 	6 : LandContour [CATEGORICAL]
# 	6 : GarageQual [CATEGORICAL]
# 	6 : BsmtFullBath [NUMERICAL]
# 	4 : GarageCond [CATEGORICAL]
# 	4 : ExterQual [CATEGORICAL]
# 	4 : ExterCond [CATEGORICAL]
# 	3 : SaleType [CATEGORICAL]
# 	3 : MSZoning [CATEGORICAL]
# 	3 : KitchenAbvGr [NUMERICAL]
# 	3 : BsmtFinSF2 [NUMERICAL]
# 	2 : Foundation [CATEGORICAL]
# 	1 : MasVnrType [CATEGORICAL]
# 	1 : LotShape [CATEGORICAL]
# 	1 : HalfBath [NUMERICAL]
# 	1 : FullBath [NUMERICAL]
# 	1 : BldgType [CATEGORICAL]
#
# Attribute in nodes with depth <= 0:
# 	12 : OverallQual [NUMERICAL]
# 	9 : GrLivArea [NUMERICAL]
# 	6 : YearRemodAdd [NUMERICAL]
# 	5 : OpenPorchSF [NUMERICAL]
# 	4 : GarageFinish [CATEGORICAL]
# 	3 : Neighborhood [CATEGORICAL]
# 	3 : LotArea [NUMERICAL]
# 	3 : KitchenQual [CATEGORICAL]
# 	1 : WoodDeckSF [NUMERICAL]
# 	1 : LotConfig [CATEGORICAL]
# 	1 : HeatingQC [CATEGORICAL]
# 	1 : GarageYrBlt [NUMERICAL]
# 	1 : GarageCars [NUMERICAL]
# 	1 : GarageArea [NUMERICAL]
# 	1 : Functional [CATEGORICAL]
# 	1 : FireplaceQu [CATEGORICAL]
#
# Attribute in nodes with depth <= 1:
# 	26 : GrLivArea [NUMERICAL]
# 	22 : OverallQual [NUMERICAL]
# 	14 : Neighborhood [CATEGORICAL]
# 	7 : FireplaceQu [CATEGORICAL]
# 	6 : YearRemodAdd [NUMERICAL]
# 	6 : OverallCond [NUMERICAL]
# 	6 : GarageArea [NUMERICAL]
# 	6 : BsmtFinSF1 [NUMERICAL]
# 	5 : OpenPorchSF [NUMERICAL]
# 	5 : GarageCars [NUMERICAL]
# 	5 : Condition1 [CATEGORICAL]
# 	4 : KitchenQual [CATEGORICAL]
# 	4 : GarageFinish [CATEGORICAL]
# 	4 : BsmtExposure [CATEGORICAL]
# 	3 : YearBuilt [NUMERICAL]
# 	3 : TotalBsmtSF [NUMERICAL]
# 	3 : LotConfig [CATEGORICAL]
# 	3 : LotArea [NUMERICAL]
# 	3 : Functional [CATEGORICAL]
# 	2 : WoodDeckSF [NUMERICAL]
# 	2 : ScreenPorch [NUMERICAL]
# 	2 : HeatingQC [CATEGORICAL]
# 	2 : GarageType [CATEGORICAL]
# 	2 : Fence [CATEGORICAL]
# 	2 : BsmtFinType1 [CATEGORICAL]
# 	1 : YrSold [NUMERICAL]
# 	1 : LotFrontage [NUMERICAL]
# 	1 : GarageYrBlt [NUMERICAL]
# 	1 : GarageQual [CATEGORICAL]
# 	1 : Fireplaces [NUMERICAL]
# 	1 : Exterior2nd [CATEGORICAL]
# 	1 : EnclosedPorch [NUMERICAL]
# 	1 : CentralAir [CATEGORICAL]
# 	1 : BsmtUnfSF [NUMERICAL]
# 	1 : BsmtFinSF2 [NUMERICAL]
# 	1 : 1stFlrSF [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	54 : GrLivArea [NUMERICAL]
# 	46 : Neighborhood [CATEGORICAL]
# 	28 : OverallQual [NUMERICAL]
# 	18 : BsmtFinSF1 [NUMERICAL]
# 	15 : TotalBsmtSF [NUMERICAL]
# 	13 : YearRemodAdd [NUMERICAL]
# 	12 : OverallCond [NUMERICAL]
# 	11 : GarageArea [NUMERICAL]
# 	10 : BsmtExposure [CATEGORICAL]
# 	9 : LotArea [NUMERICAL]
# 	9 : GarageCars [NUMERICAL]
# 	9 : FireplaceQu [CATEGORICAL]
# 	8 : KitchenQual [CATEGORICAL]
# 	7 : SaleCondition [CATEGORICAL]
# 	7 : OpenPorchSF [NUMERICAL]
# 	7 : Functional [CATEGORICAL]
# 	7 : Condition1 [CATEGORICAL]
# 	7 : BsmtFinType1 [CATEGORICAL]
# 	7 : 1stFlrSF [NUMERICAL]
# 	6 : YearBuilt [NUMERICAL]
# 	5 : WoodDeckSF [NUMERICAL]
# 	5 : ScreenPorch [NUMERICAL]
# 	5 : LotConfig [CATEGORICAL]
# 	4 : TotRmsAbvGrd [NUMERICAL]
# 	4 : GarageYrBlt [NUMERICAL]
# 	4 : GarageFinish [CATEGORICAL]
# 	4 : Fence [CATEGORICAL]
# 	4 : BsmtQual [CATEGORICAL]
# 	3 : RoofStyle [CATEGORICAL]
# 	3 : Fireplaces [NUMERICAL]
# 	3 : CentralAir [CATEGORICAL]
# 	2 : YrSold [NUMERICAL]
# 	2 : LotFrontage [NUMERICAL]
# 	2 : HeatingQC [CATEGORICAL]
# 	2 : GarageType [CATEGORICAL]
# 	2 : GarageCond [CATEGORICAL]
# 	2 : Exterior1st [CATEGORICAL]
# 	2 : EnclosedPorch [NUMERICAL]
# 	2 : BsmtUnfSF [NUMERICAL]
# 	2 : BsmtFullBath [NUMERICAL]
# 	2 : BsmtFinSF2 [NUMERICAL]
# 	1 : MoSold [NUMERICAL]
# 	1 : MSSubClass [NUMERICAL]
# 	1 : LotShape [CATEGORICAL]
# 	1 : LandContour [CATEGORICAL]
# 	1 : KitchenAbvGr [NUMERICAL]
# 	1 : GarageQual [CATEGORICAL]
# 	1 : Exterior2nd [CATEGORICAL]
# 	1 : ExterQual [CATEGORICAL]
# 	1 : BsmtCond [CATEGORICAL]
#
# Attribute in nodes with depth <= 3:
# 	115 : Neighborhood [CATEGORICAL]
# 	93 : GrLivArea [NUMERICAL]
# 	37 : OverallQual [NUMERICAL]
# 	36 : BsmtFinSF1 [NUMERICAL]
# 	28 : LotArea [NUMERICAL]
# 	27 : OverallCond [NUMERICAL]
# 	25 : TotalBsmtSF [NUMERICAL]
# 	23 : GarageArea [NUMERICAL]
# 	23 : 1stFlrSF [NUMERICAL]
# 	19 : SaleCondition [CATEGORICAL]
# 	19 : Exterior1st [CATEGORICAL]
# 	18 : YearRemodAdd [NUMERICAL]
# 	14 : YearBuilt [NUMERICAL]
# 	14 : ScreenPorch [NUMERICAL]
# 	14 : Functional [CATEGORICAL]
# 	14 : FireplaceQu [CATEGORICAL]
# 	14 : BsmtFinType1 [CATEGORICAL]
# 	13 : BsmtExposure [CATEGORICAL]
# 	11 : WoodDeckSF [NUMERICAL]
# 	11 : Condition1 [CATEGORICAL]
# 	10 : OpenPorchSF [NUMERICAL]
# 	10 : GarageYrBlt [NUMERICAL]
# 	10 : GarageCars [NUMERICAL]
# 	10 : Exterior2nd [CATEGORICAL]
# 	9 : MoSold [NUMERICAL]
# 	9 : KitchenQual [CATEGORICAL]
# 	9 : BsmtUnfSF [NUMERICAL]
# 	8 : LotConfig [CATEGORICAL]
# 	7 : Fence [CATEGORICAL]
# 	7 : CentralAir [CATEGORICAL]
# 	6 : MasVnrArea [NUMERICAL]
# 	6 : LotFrontage [NUMERICAL]
# 	6 : GarageType [CATEGORICAL]
# 	6 : BsmtQual [CATEGORICAL]
# 	6 : 2ndFlrSF [NUMERICAL]
# 	5 : TotRmsAbvGrd [NUMERICAL]
# 	5 : GarageFinish [CATEGORICAL]
# 	5 : Fireplaces [NUMERICAL]
# 	5 : EnclosedPorch [NUMERICAL]
# 	4 : YrSold [NUMERICAL]
# 	4 : RoofStyle [CATEGORICAL]
# 	4 : LandContour [CATEGORICAL]
# 	3 : MSZoning [CATEGORICAL]
# 	3 : KitchenAbvGr [NUMERICAL]
# 	3 : HeatingQC [CATEGORICAL]
# 	3 : GarageQual [CATEGORICAL]
# 	3 : BsmtFullBath [NUMERICAL]
# 	3 : BsmtCond [CATEGORICAL]
# 	2 : MSSubClass [NUMERICAL]
# 	2 : HouseStyle [CATEGORICAL]
# 	2 : GarageCond [CATEGORICAL]
# 	2 : BsmtFinSF2 [NUMERICAL]
# 	1 : PavedDrive [CATEGORICAL]
# 	1 : LotShape [CATEGORICAL]
# 	1 : ExterQual [CATEGORICAL]
#
# Attribute in nodes with depth <= 5:
# 	200 : Neighborhood [CATEGORICAL]
# 	131 : GrLivArea [NUMERICAL]
# 	61 : BsmtFinSF1 [NUMERICAL]
# 	60 : LotArea [NUMERICAL]
# 	47 : TotalBsmtSF [NUMERICAL]
# 	45 : OverallCond [NUMERICAL]
# 	44 : Exterior1st [CATEGORICAL]
# 	42 : 1stFlrSF [NUMERICAL]
# 	40 : OverallQual [NUMERICAL]
# 	37 : GarageArea [NUMERICAL]
# 	33 : YearRemodAdd [NUMERICAL]
# 	33 : SaleCondition [CATEGORICAL]
# 	33 : BsmtFinType1 [CATEGORICAL]
# 	30 : YearBuilt [NUMERICAL]
# 	28 : OpenPorchSF [NUMERICAL]
# 	27 : Exterior2nd [CATEGORICAL]
# 	25 : BsmtExposure [CATEGORICAL]
# 	23 : MoSold [NUMERICAL]
# 	22 : FireplaceQu [CATEGORICAL]
# 	21 : BsmtUnfSF [NUMERICAL]
# 	20 : GarageYrBlt [NUMERICAL]
# 	19 : KitchenQual [CATEGORICAL]
# 	19 : 2ndFlrSF [NUMERICAL]
# 	17 : WoodDeckSF [NUMERICAL]
# 	17 : Functional [CATEGORICAL]
# 	16 : ScreenPorch [NUMERICAL]
# 	16 : LotFrontage [NUMERICAL]
# 	15 : LotConfig [CATEGORICAL]
# 	15 : Condition1 [CATEGORICAL]
# 	14 : GarageType [CATEGORICAL]
# 	13 : BsmtQual [CATEGORICAL]
# 	12 : GarageCars [NUMERICAL]
# 	11 : MasVnrArea [NUMERICAL]
# 	11 : Fence [CATEGORICAL]
# 	10 : YrSold [NUMERICAL]
# 	10 : HeatingQC [CATEGORICAL]
# 	9 : GarageFinish [CATEGORICAL]
# 	9 : CentralAir [CATEGORICAL]
# 	8 : EnclosedPorch [NUMERICAL]
# 	7 : TotRmsAbvGrd [NUMERICAL]
# 	7 : HouseStyle [CATEGORICAL]
# 	7 : Fireplaces [NUMERICAL]
# 	7 : BsmtCond [CATEGORICAL]
# 	7 : BedroomAbvGr [NUMERICAL]
# 	6 : RoofStyle [CATEGORICAL]
# 	6 : PavedDrive [CATEGORICAL]
# 	6 : MSSubClass [NUMERICAL]
# 	6 : LandContour [CATEGORICAL]
# 	6 : GarageQual [CATEGORICAL]
# 	6 : BsmtFullBath [NUMERICAL]
# 	4 : GarageCond [CATEGORICAL]
# 	4 : ExterQual [CATEGORICAL]
# 	4 : ExterCond [CATEGORICAL]
# 	3 : SaleType [CATEGORICAL]
# 	3 : MSZoning [CATEGORICAL]
# 	3 : KitchenAbvGr [NUMERICAL]
# 	3 : BsmtFinSF2 [NUMERICAL]
# 	2 : Foundation [CATEGORICAL]
# 	1 : MasVnrType [CATEGORICAL]
# 	1 : LotShape [CATEGORICAL]
# 	1 : HalfBath [NUMERICAL]
# 	1 : FullBath [NUMERICAL]
# 	1 : BldgType [CATEGORICAL]
#
# Condition type in nodes:
# 	768 : HigherCondition
# 	577 : ContainsBitmapCondition
# Condition type in nodes with depth <= 0:
# 	39 : HigherCondition
# 	14 : ContainsBitmapCondition
# Condition type in nodes with depth <= 1:
# 	103 : HigherCondition
# 	55 : ContainsBitmapCondition
# Condition type in nodes with depth <= 2:
# 	225 : HigherCondition
# 	138 : ContainsBitmapCondition
# Condition type in nodes with depth <= 3:
# 	444 : HigherCondition
# 	304 : ContainsBitmapCondition
# Condition type in nodes with depth <= 5:
# 	768 : HigherCondition
# 	577 : ContainsBitmapCondition
#
# Training logs:
# Number of iteration to final model: 53
# 	Iter:1 train-loss:0.361702 valid-loss:0.325674  train-rmse:0.361702 valid-rmse:0.325674
# 	Iter:2 train-loss:0.332201 valid-loss:0.299780  train-rmse:0.332201 valid-rmse:0.299780
# 	Iter:3 train-loss:0.305554 valid-loss:0.274875  train-rmse:0.305554 valid-rmse:0.274875
# 	Iter:4 train-loss:0.281833 valid-loss:0.253503  train-rmse:0.281833 valid-rmse:0.253503
# 	Iter:5 train-loss:0.260053 valid-loss:0.234226  train-rmse:0.260053 valid-rmse:0.234226
# 	Iter:6 train-loss:0.240565 valid-loss:0.218341  train-rmse:0.240565 valid-rmse:0.218341
# 	Iter:16 train-loss:0.123874 valid-loss:0.127194  train-rmse:0.123874 valid-rmse:0.127194
# 	Iter:26 train-loss:0.080387 valid-loss:0.105928  train-rmse:0.080387 valid-rmse:0.105928
# 	Iter:36 train-loss:0.062015 valid-loss:0.101592  train-rmse:0.062015 valid-rmse:0.101592
# 	Iter:46 train-loss:0.052647 valid-loss:0.100982  train-rmse:0.052647 valid-rmse:0.100982
# 	Iter:56 train-loss:0.047262 valid-loss:0.100864  train-rmse:0.047262 valid-rmse:0.100864
# 	Iter:66 train-loss:0.043027 valid-loss:0.101505  train-rmse:0.043027 valid-rmse:0.101505
# 	Iter:76 train-loss:0.040262 valid-loss:0.101027  train-rmse:0.040262 valid-rmse:0.101027
#
# None
# 1/1 [==============================] - 0s 239ms/step
# RMSE en valid (log1p scale): 0.131872
# RMSE en precio (valid): 24634.45 USD aprox.
#
# Top features (NUM_AS_ROOT):
#   - OverallQual: 12.0
#   - GrLivArea: 9.0
#   - YearRemodAdd: 6.0
#   - OpenPorchSF: 5.0
#   - GarageFinish: 4.0
#   - KitchenQual: 3.0
#   - LotArea: 3.0
#   - Neighborhood: 3.0
#   - FireplaceQu: 1.0
#   - Functional: 1.0
#   - GarageArea: 1.0
#   - GarageCars: 1.0
#   - GarageYrBlt: 1.0
#   - HeatingQC: 1.0
#   - LotConfig: 1.0
#
# Reentrenando modelo final con todo el train (train+valid)...
# Use /tmp/tmpjd4kqt32 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:01.407526. Found 1460 examples.
# Training model...
# Model trained in 0:00:02.737197
# Compiling model...
# Model compiled.
# 2/2 [==============================] - 1s 21ms/step
#      Id      SalePrice
# 0  1461  116439.351562
# 1  1462  158448.656250
# 2  1463  187553.500000
# 3  1464  183205.312500
# 4  1465  190252.859375
